# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df=pd.read_csv('../input/gtd/globalterrorismdb_0718dist.csv', encoding='iso-8859-1')
# Out:
# /opt/conda/lib/python3.6/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
mcc=[]
cmatrix ={1:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},2:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},3:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},4:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},5:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},6:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},7:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},8:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},9:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},10:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},11:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},12:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0},13:{'weap_s':0,'weap_ns':0,'nweap_s':0,'nweap_ns':0}}
for i in range(len(df['weaptype1'])):
        if df['success'][i]==1:
            cmatrix[df['weaptype1'][i]]['weap_s']+=1
            for j in range(len(cmatrix)):
                if j!=cmatrix[df['weaptype1'][i]]:
                    cmatrix[j+1]['nweap_s']+=1
        elif df['success'][i]==0:
            cmatrix[df['weaptype1'][i]]['weap_ns']+=1
            for j in range(len(cmatrix)):
                if j!=cmatrix[df['weaptype1'][i]]:
                    cmatrix[j+1]['nweap_ns']+=1

# %%
weap_type=['Biological','Chemical','Radiological','Nuclear','Firearms','Explosives','Fake Weapons','Incendiary','Melee','Vehicle','Sabotage Equipment','Other','Unknown']
for i in range(len(cmatrix)):
    mcc=(cmatrix[i+1]['weap_s']*cmatrix[i+1]['nweap_ns']-cmatrix[i+1]['weap_ns']*cmatrix[i+1]['nweap_s'])/((cmatrix[i+1]['weap_s']+cmatrix[i+1]['weap_ns'])*(cmatrix[i+1]['weap_s']+cmatrix[i+1]['nweap_s'])*(cmatrix[i+1]['nweap_ns']+cmatrix[i+1]['weap_ns'])*(cmatrix[i+1]['nweap_s']+cmatrix[i+1]['nweap_s'])+0.0000000000000000000000000000001)**0.5
    print(weap_type[i],mcc)
# Out:
# Biological -0.015298896858441218
# Chemical -0.013296190976572171
# Radiological -0.0156760979808965
# Nuclear 0.0
# Firearms 0.03683880636144487
# Explosives -0.02927713158838924
# Fake Weapons -0.011090388481581202
# Incendiary 0.028718561628144512
# Melee 0.0031435010199631
# Vehicle -0.0019163392454151999
# Sabotage Equipment 0.003574085572931093
# Other -0.005994446292623448
# Unknown -0.0026743204246978476

# %% [markdown]
# Weapon type is a poor measure to directly predict the success.
